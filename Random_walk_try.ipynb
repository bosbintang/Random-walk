# %% [markdown]
# <a href="https://colab.research.google.com/github/bosbintang/Random-walk/blob/main/Random_walk_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
S=np.zeros(10001)
S[0]=0
V=np.zeros(10001)
n=1
p=0.5
for i in range(10000):
  for t in range (10000):
    S[t+1]=S[t]+(2*(np.random.binomial(1,0.5))-1)*(1/10000)
  V[i]=S[t]
  plt.plot(S)

# %%
S=np.zeros(10001)
S[0]=0
V=np.zeros(10001)
n=1
p=0.5
for t in range (10000):
  S[t+1]=S[t]+(2*(np.random.binomial(1,0.5))-1)*(1/10000)
plt.plot(S)

# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np

S=np.zeros(10001)
S[0]=1000
V=np.zeros(10001)
mu=0.05
p=0.5
for t in range (10000):
  S[t+1]=S[t]+mu*S[t]*(1/10000)+S[t]*(2*(np.random.binomial(1,0.5))-1)*(1/10000)
plt.plot(S)

# %%
plt.hist(S)

# %%
plt.hist(V)

# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np

S=np.zeros(10001)
S[0]=0
V=np.zeros(10001)
n=1
p=0.5
for i in range(10000):
  for t in range (10000):
    S[t+1]=S[t]+(2*(np.random.binomial(1,0.5))-1)*(1/10000)
  V[i]=S[t]
  plt.plot(S)

# %%
plt.hist(V)
